# %%
from collections import namedtuple

# %% [markdown]
# 1. Download url
# 2. Download folder (compressed file)
# 3. Extract folder (extracted file)
# 4. Train dataset folder
# 5. Test dataset folder

# %%
DataIngestionConfig=namedtuple("DataIngestionConfig",
["dataset_download_url","tgz_download_dir","raw_data_dir","ingested_train_dir","ingested_test_dir"])

# %%
data_ingestion_config=DataIngestionConfig(dataset_download_url="astcd",
                    tgz_download_dir='cfdgjf',
                    raw_data_dir='hjdbf',
                    ingested_train_dir='gdhhsggd',
                    ingested_test_dir='hdgfxvs')

# %%
data_ingestion_config
# Out:
# DataIngestionConfig(dataset_download_url='astcd', tgz_download_dir='cfdgjf', raw_data_dir='hjdbf', ingested_train_dir='gdhhsggd', ingested_test_dir='hdgfxvs')

# %%
import yaml

# %%
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\win\\Desktop\\ML project\\Machine_learning_project'

# %%
os.chdir("c:\\Users\\win\\Desktop\\ML project\\Machine_learning_project")

# %%
os.getcwd()
# Out:
# 'c:\\Users\\win\\Desktop\\ML project\\Machine_learning_project'

# %%
os.listdir(".")
# Out:
# ['.dockerignore',
#  '.github',
#  '.gitignore',
#  'app.py',
#  'config',
#  'Dockerfile',
#  'housing',
#  'housing.egg-info',
#  'housing_logs',
#  'housing_predictor.egg-info',
#  'LICENSE',
#  'notebook',
#  'Procfile',
#  'README.md',
#  'requirements.txt',
#  'setup.py',
#  'venv']

# %%
config_file_path=os.path.join("config","config.yaml")

# %%
config_file_path
# Out:
# 'config\\config.yaml'

# %%
os.path.exists(config_file_path)
# Out:
# True

# %%
from housing.constant import *

# %%
os.getcwd()
# Out:
# 'c:\\Users\\win\\Desktop\\ML project\\Machine_learning_project'

# %%
from housing.constant import CONFIG_FILE_PATH
print(CONFIG_FILE_PATH)
# Out:
# c:\Users\win\Desktop\ML project\Machine_learning_project\config\config.yaml

# %%
from housing.config.configuration import Configuration
config = Configuration()
# Out:
# [24/Dec/2025 13:35:19] INFO - Training Pipeline config:TrainingPipeline(artifact_dir='c:\\Users\\win\\Desktop\\ML project\\Machine_learning_project\\housing\\artifact')

# %%
config.get_training_pipeline_config()
# Out:
# [24/Dec/2025 13:35:19] INFO - Training Pipeline config:TrainingPipeline(artifact_dir='c:\\Users\\win\\Desktop\\ML project\\Machine_learning_project\\housing\\artifact')
# TrainingPipeline(artifact_dir='c:\\Users\\win\\Desktop\\ML project\\Machine_learning_project\\housing\\artifact')

# %%
config.get_data_ingestion_config()
# Out:
# [24/Dec/2025 13:35:19] INFO - Data Ingestion config:DataIngestionConfig(dataset_download_url='https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz', tgz_download_dir='c:\\Users\\win\\Desktop\\ML project\\Machine_learning_project\\housing\\artifact\\data_ingestion\\2025-12-24-13-26-46\\tgz_data', raw_data_dir='c:\\Users\\win\\Desktop\\ML project\\Machine_learning_project\\housing\\artifact\\data_ingestion\\2025-12-24-13-26-46\\raw_data', ingested_train_dir='c:\\Users\\win\\Desktop\\ML project\\Machine_learning_project\\housing\\artifact\\data_ingestion\\2025-12-24-13-26-46\\ingested_data\\train', ingested_test_dir='c:\\Users\\win\\Desktop\\ML project\\Machine_learning_project\\housing\\artifact\\data_ingestion\\2025-12-24-13-26-46\\ingested_data\\test')
# ...
